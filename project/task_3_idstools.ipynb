# %%
from idstools._config import load_config
from idstools._objects import Target
from idstools.preparation import DataPreparation
from idstools.optimization import ModelOptimization

# %%
# Load configuration
config = load_config("../config/idstools/TestModel.yaml")

# %%
# Train Data
id = 1
input_path = "data/BikeRentalDaily_train.csv"
input_delimiter = ";"
label = "cnt"
index = "instant"

# %%
# Test Data
id = 2
input_path = "data/BikeRentalDaily_test.csv"
input_delimiter = ";"
label = "cnt"
index = "instant"

# %%
# Initialize Targets
train_target = Target(id, input_path, input_delimiter, label, index)
test_target = Target(id, input_path, input_delimiter, label, index)
# Out:
# 2024-03-02 12:49:54,069 [_objects] [INFO] - Initializing TargetData object.
# 2024-03-02 12:49:54,071 [_helpers] [INFO] - Reading data from:
# /home/davidrmn/Studies/introduction-data-science/data/BikeRentalDaily_test.csv
# 2024-03-02 12:49:54,074 [_objects] [INFO] - Using id: 2
# 2024-03-02 12:49:54,075 [_objects] [INFO] - Using label: cnt
# 2024-03-02 12:49:54,075 [_objects] [INFO] - Using index: instant
# 2024-03-02 12:49:54,075 [_objects] [INFO] - No features provided.
# 2024-03-02 12:49:54,076 [_objects] [INFO] - No environment name provided.
# Using default environment name: SELF_EXECUTED
# 2024-03-02 12:49:54,076 [_objects] [INFO] - No step name provided.
# 2024-03-02 12:49:54,076 [_objects] [INFO] - Output path not provided.
# Using default output path: /home/davidrmn/Studies/introduction-data-science/results
# 2024-03-02 12:49:54,077 [_objects] [INFO] - Initializing TargetData object.
# 2024-03-02 12:49:54,077 [_helpers] [INFO] - Reading data from:
# /home/davidrmn/Studies/introduction-data-science/data/BikeRentalDaily_test.csv
# 2024-03-02 12:49:54,080 [_objects] [INFO] - Using id: 2
# 2024-03-02 12:49:54,080 [_objects] [INFO] - Using label: cnt
# 2024-03-02 12:49:54,080 [_objects] [INFO] - Using index: instant
# 2024-03-02 12:49:54,081 [_objects] [INFO] - No features provided.
# 2024-03-02 12:49:54,081 [_objects] [INFO] - No environment name provided.
# Using default environment name: SELF_EXECUTED
# 2024-03-02 12:49:54,081 [_objects] [INFO] - No step name provided.
# 2024-03-02 12:49:54,082 [_objects] [INFO] - Output path not provided.
# Using default output path: /home/davidrmn/Studies/introduction-data-science/results

# %%
# Preprocessing Pipeline
pipeline = config.default.preprocessing.preparation.DataPreparation.pipeline

# %%
# Initialize DataPreparation 
preprcessing_pipeline = DataPreparation([train_target, test_target], pipeline=pipeline)
# Out:
# 2024-03-02 12:49:54,169 [preparation] [INFO] - Initializing DataPreparation for multiple targets.

# %%
train_target.data.describe().T
# Out:
#                  count         mean          std         min          25%  \
# season           121.0     2.652893     1.123319    1.000000     2.000000
# yr               132.0     0.515152     0.501674    0.000000     0.000000
# mnth             132.0     6.750000     3.497818    1.000000     3.750000
# holiday          132.0     0.022727     0.149600    0.000000     0.000000
# weekday          132.0     2.590909     2.154188   -1.000000     1.000000
# workingday       132.0     0.704545     0.457985    0.000000     0.000000
# weathersit       132.0     1.371212     0.558150    1.000000     1.000000
# temp             132.0    19.844301     7.827241    3.895700    13.300000
# atemp            132.0     0.477679     0.173988    0.117930     0.325754
# hum              126.0    93.645418    21.467624    0.000000    80.692913
# windspeed        132.0     0.185349     0.068409    0.042304     0.135898
# leaflets         132.0   749.553030   178.500040  458.000000   583.500000
# price reduction  132.0     0.166667     0.374098    0.000000     0.000000
# casual           132.0   999.825758  2313.057147    9.000000   330.750000
# registered       132.0  3755.166667  1651.661972  416.000000  2532.750000
# cnt              132.0  4754.992424  3118.721529  431.000000  3289.500000
#
#                          50%          75%           max
# season              3.000000     4.000000      4.000000
# yr                  1.000000     1.000000      1.000000
# mnth                7.000000    10.000000     12.000000
# holiday             0.000000     0.000000      1.000000
# weekday             2.000000     5.000000      6.000000
# workingday          1.000000     1.000000      1.000000
# weathersit          1.000000     2.000000      3.000000
# temp               19.200000    27.366675     33.933300
# atemp               0.470002     0.635919      0.840896
# hum                93.468750   107.484413    139.500000
# windspeed           0.179102     0.227141      0.385571
# leaflets          745.000000   918.000000   1028.000000
# price reduction     0.000000     0.000000      1.000000
# casual            693.500000  1138.500000  26506.000000
# registered       3705.000000  5112.000000   6803.000000
# cnt              4621.000000  6145.250000  32472.000000

# %%
# Run DataPreparation
preprcessing_pipeline.run()
# Out:
# 2024-03-02 12:49:54,208 [preparation] [INFO] - Pipeline created:
# _StandardScaler:
# - target:
#   - leaflets
#   - hum
# _CustomTransformer:
# - func: target_to_datetime
#   module: idstools._transformer
#   config:
#     target: dteday
#     format: '%d.%m.%Y'
# - func: impute_season
#   module: idstools._transformer
#   config:
#     target: season
#     date: dteday
# - func: negative_to_nan
#   module: idstools._transformer
#   config:
#     target: windspeed
# - func: process_weekday
#   module: idstools._transformer
#   config:
#     target: weekday
#     date: dteday
# - func: remove_outliers
#   module: idstools._transformer
#   config:
#     target: cnt
# _OneHotEncoder:
# - target: mnth
#   config:
#     prefix: mnth
#     dtype: int
#     drop_first: true
# - target: weekday
#   config:
#     prefix: weekday
#     dtype: int
#     drop_first: true
# - target: weathersit
#   config:
#     prefix: weathersit
#     dtype: int
#     drop_first: true
# _SimpleImputer:
# - target:
#   - hum
#   - windspeed
#   config:
#     strategy: mean
# _FeatureDropper:
# - target:
#   - casual
#   - registered
#   - temp
#   - dteday
#   - workingday
#   config:
#     axis: 1
#     errors: ignore
# .
# 2024-03-02 12:49:54,209 [preparation] [INFO] - Scaling feature leaflets.
# 2024-03-02 12:49:54,212 [preparation] [INFO] - Scaling feature hum.
# 2024-03-02 12:49:54,220 [_transformer] [INFO] - Converting target column 'dteday' to datetime.
# 2024-03-02 12:49:54,222 [_transformer] [INFO] - Imputing season based on target column 'dteday' value.
# 2024-03-02 12:49:54,223 [_transformer] [INFO] - Replacing negative values with NaN in target column 'windspeed'.
# 2024-03-02 12:49:54,224 [_transformer] [INFO] - Mapping weekday based on 'dteday' column value.
# 2024-03-02 12:49:54,225 [_transformer] [INFO] - Dropping outliers from target column 'cnt'.
# 2024-03-02 12:49:54,236 [preparation] [INFO] - Pipeline processing completed for target BikeRentalDaily_test in SELF_EXECUTED:STEP.
# 2024-03-02 12:49:54,237 [_helpers] [INFO] - Writing data to:
# /home/davidrmn/Studies/introduction-data-science/results/SELF_EXECUTED/STEP/BikeRentalDaily_test_processed.csv
# 2024-03-02 12:49:54,239 [preparation] [INFO] - Processed data written to /home/davidrmn/Studies/introduction-data-science/results/SELF_EXECUTED/STEP/BikeRentalDaily_test_processed.csv for target 2 in SELF_EXECUTED:STEP.
# 2024-03-02 12:49:54,240 [preparation] [INFO] - Scaling feature leaflets.
# 2024-03-02 12:49:54,243 [preparation] [INFO] - Scaling feature hum.
# 2024-03-02 12:49:54,244 [_transformer] [INFO] - Converting target column 'dteday' to datetime.
# 2024-03-02 12:49:54,245 [_transformer] [INFO] - Imputing season based on target column 'dteday' value.
# 2024-03-02 12:49:54,246 [_transformer] [INFO] - Replacing negative values with NaN in target column 'windspeed'.
# 2024-03-02 12:49:54,247 [_transformer] [INFO] - Mapping weekday based on 'dteday' column value.
# 2024-03-02 12:49:54,248 [_transformer] [INFO] - Dropping outliers from target column 'cnt'.
# 2024-03-02 12:49:54,258 [preparation] [INFO] - Pipeline processing completed for target BikeRentalDaily_test in SELF_EXECUTED:STEP.
# 2024-03-02 12:49:54,259 [_helpers] [INFO] - Writing data to:
# /home/davidrmn/Studies/introduction-data-science/results/SELF_EXECUTED/STEP/BikeRentalDaily_test_processed.csv
# 2024-03-02 12:49:54,261 [preparation] [INFO] - Processed data written to /home/davidrmn/Studies/introduction-data-science/results/SELF_EXECUTED/STEP/BikeRentalDaily_test_processed.csv for target 2 in SELF_EXECUTED:STEP.

# %%
train_target.processed_data.describe().T
# Out:
#                  count         mean          std         min          25%  \
# season           131.0     2.671756     1.112466    1.000000     2.000000
# yr               131.0     0.511450     0.501788    0.000000     0.000000
# holiday          131.0     0.022901     0.150161    0.000000     0.000000
# atemp            131.0     0.477278     0.174595    0.117930     0.325125
# hum              131.0     0.004567     0.983211   -4.379583    -0.600166
